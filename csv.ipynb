# %%
b = open("data.csv",'x')
# c = b.read()
# print(c)
b.close()

# %%
b = open("data.csv",'r')
c = b.read()
print(c)
b.close()
# Out:
# Name,Age,Address,Phone
# Ram,34,Kathmandu,9856554543
# Shyam,23,Patan,9867665654
# Hari,23,Bara,9800445432
# Nabin,12,Kathmandu,9078776654
# Sita,34,Bhaktapur,9807887876
# Sahana,56,Sauhara,9890556789

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df
# Out:
#    Sn    Name  Age    Address       Phone
# 0   1     Ram   34  Kathmandu  9856554543
# 1   2   Shyam   23      Patan  9867665654
# 2   3    Hari   23       Bara  9800445432
# 3   4   Nabin   12  Kathmandu  9078776654
# 4   5    Sita   34  Bhaktapur  9807887876
# 5   6  Sahana   56    Sauhara  9890556789

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df.head()
# Out:
#    Sn   Name  Age    Address       Phone
# 0   1    Ram   34  Kathmandu  9856554543
# 1   2  Shyam   23      Patan  9867665654
# 2   3   Hari   23       Bara  9800445432

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df.tail(3)
# Out:
#    Sn    Name  Age    Address       Phone
# 3   4   Nabin   12  Kathmandu  9078776654
# 4   5    Sita   34  Bhaktapur  9807887876
# 5   6  Sahana   56    Sauhara  9890556789

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df
# Out:
#       Name  Age    Address       Phone
# Sn
# 1      Ram   34  Kathmandu  9856554543
# 2    Shyam   23      Patan  9867665654
# 3     Hari   23       Bara  9800445432
# 4    Nabin   12  Kathmandu  9078776654
# 5     Sita   34  Bhaktapur  9807887876
# 6   Sahana   56    Sauhara  9890556789

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn',usecols = ['Sn','Name','Age'])
df
# Out:
#       Name  Age
# Sn
# 1      Ram   34
# 2    Shyam   23
# 3     Hari   23
# 4    Nabin   12
# 5     Sita   34
# 6   Sahana   56

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df.iloc[0:4]
# Out:
#      Name  Age    Address       Phone
# Sn
# 1     Ram   34  Kathmandu  9856554543
# 2   Shyam   23      Patan  9867665654
# 3    Hari   23       Bara  9800445432
# 4   Nabin   12  Kathmandu  9078776654

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df.loc[1:4]
# Out:
#      Name  Age    Address       Phone
# Sn
# 1     Ram   34  Kathmandu  9856554543
# 2   Shyam   23      Patan  9867665654
# 3    Hari   23       Bara  9800445432
# 4   Nabin   12  Kathmandu  9078776654

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Name')
df
# Out:
#         Sn  Age    Address       Phone
# Name
# Ram      1   34  Kathmandu  9856554543
# Shyam    2   23      Patan  9867665654
# Hari     3   23       Bara  9800445432
# Nabin    4   12  Kathmandu  9078776654
# Sita     5   34  Bhaktapur  9807887876
# Sahana   6   56    Sauhara  9890556789

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Name')
df.loc["Shyam":"Sita"]
# Out:
#        Sn  Age    Address       Phone
# Name
# Shyam   2   23      Patan  9867665654
# Hari    3   23       Bara  9800445432
# Nabin   4   12  Kathmandu  9078776654
# Sita    5   34  Bhaktapur  9807887876

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df[df['Address'] == 'Kathmandu']
# Out:
#      Name  Age    Address       Phone
# Sn
# 1     Ram   34  Kathmandu  9856554543
# 4   Nabin   12  Kathmandu  9078776654

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df[(df['Age'] <50) & (df['Address'] == "Kathmandu")]
# Out:
#      Name  Age    Address       Phone
# Sn
# 1     Ram   34  Kathmandu  9856554543
# 4   Nabin   12  Kathmandu  9078776654

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Name')
df1 = df.loc["Shyam":"Sita"]
df1.to_csv('data1.csv')

# %%
import pandas as pd
data = {'Names':['Ram', 'Shyam', 'Hari','Bikash', 'Samrat'],
                   'Address':['Kathmandu','Palpa','Pyuthan','Bhaktapur','Patan'],
            'Age':[21, 22, 20, 19, 18]}


df = pd.DataFrame(data)
df.to_csv('boooks.csv')
df.head()
# Out:
#     Names    Address  Age
# 0     Ram  Kathmandu   21
# 1   Shyam      Palpa   22
# 2    Hari    Pyuthan   20
# 3  Bikash  Bhaktapur   19
# 4  Samrat      Patan   18

# %%
import csv   
fields=['Kamal','28','Baluwatar']
f = open('boks.csv', 'a')
x = csv.writer(f)
x.writerow(fields)
f.close()

# %%
import csv
with open('boooks.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        print(dict(row))
# Out:
# {'': '0', 'Names': 'Ram', 'Address': 'Kathmandu', 'Age': '21'}
# {'': '1', 'Names': 'Shyam', 'Address': 'Palpa', 'Age': '22'}
# {'': '2', 'Names': 'Hari', 'Address': 'Pyuthan', 'Age': '20'}
# {'': '3', 'Names': 'Bikash', 'Address': 'Bhaktapur', 'Age': '19'}
# {'': '4', 'Names': 'Samrat', 'Address': 'Patan', 'Age': '18'}

# %%
dict([('', '0'), ('Names', 'Ram'), ('Address', 'Kathmandu'), ('Age', '21')])
# Out:
# {'': '0', 'Names': 'Ram', 'Address': 'Kathmandu', 'Age': '21'}

# %%
import csv
csv_columns = ['Name', 'Age', 'Address']
dict = [
    {'Name':'Aayush','Age':23,'Address':'Katmandu'},
    {'Name':'Shyam','Age':33,'Address':'Patan'}
]

csvfile = open("data.csv", 'w')
writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
writer.writeheader()
for data in dict:
    writer.writerow(data)
